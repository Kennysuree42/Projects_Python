# %%
#calling the file by it's name

# %run Hospital_Main_OPD.ipynb
# %run Hospital_Doctor_Details.ipynb
# %run Hospital_Main_Appointment.ipynb
# %run Hospital_Main_Reports.ipynb

import warnings

# Ignore all warnings 
warnings.filterwarnings("ignore")

while(True):
    print(" = " * 40)
    
    print("======================================= Hospital Management System =======================================")
    
    print("1. OPD")
    
    print("2. Doctor Details")
    
    print("3. Appoinment")
    
    print("4. Reports")
    
    print("5. Exit")
    
    print(" = "* 40)
    
    choice = int(input("Enter Your Choice: ")) 
            
        
    if choice == 1:
        
        while (True):
            
            print("======================================= OPD DETAILS =======================================")
            
            print("1. New Entry of OPD")
            
            print("2. Edit or Modify the details of OPD")
            
            print("3. Delete OPD")
            
            print("4. Search OPD")
            
            print("5. Back to Main Menu")
            
            choice = int(input("enter your choice: "))
            
            if choice == 1:
                
                # The addition of OPD details (function calling)
                rec_addopd()
            
            elif choice == 2:
                
                # The modification of OPD details (function calling)
                rec_editopd()
            
            elif choice == 3:
                
                # The deletion of OPD details (function calling)
                rec_deleteopd()
            
            elif choice == 4:
                
                # The Selection of OPD details (function calling)
                rec_selectopd()
            
            elif choice == 5:
                
                # Going back to Main menu for further selection
                print("Back to Main Menu")
                
                # breaking out of the loop
                break
        else:
            
            # printing the Response for the Invalid entry
            print("Invalid entry")
            
    
    # if the user choose option 2
    elif choice == 2:
         
        while(True):
            
            print("======================================= DOCTOR DETAILS =======================================")
            
            print("1. Adding New Details of Doctor")
            
            print("2. Editing or Modification of the Details of Doctor")
            
            print("3. Deletion of the Details of Doctor")
            
            print("4. Search Details of Doctor")
            
            print("5. Back to Main Menu")
            
            choice = int(input("enter your choice: "))
            
            if choice == 1:
                # function call
                rec_adddoc()
                
            elif choice == 2:
                # function call
                rec_editdoc()
                
            elif choice == 3:
                # function call
                rec_deletedoc()
                
            elif choice == 4:
                # function call
                rec_selectdoc()
                
            elif choice == 5:
                
                print("Back to Main Menu")
                # break out of the loop
                break
        else:
            print("Invalid Entry")
            
            
    elif choice ==3:
        
        
        while(True):
            
            print("======================================= APPOINTMENT DETAILS =======================================")
            
            print("1.Appointment")
            
            print("2.Appoinment Edit")
            
            print("3.Back to Main Menu")
            
            choice = int(input("enter your choice: "))
            
            if choice == 1:
                 # function call
                rec_appointment()
                
            elif choice == 2:
                 # function call
                rec_appointmentedit()
            
            elif choice == 3:
                 # function call
                print("Back to Main Menu")
                # breaking out of the loop
                break
        else:
            print("Invalid Entry")
    
    elif choice == 4:
        
        while(True):
            
            # reports
            print("======================================= REPORTS =======================================")
            
            print("1. Display the Doctors List")
            
            print("2. Display the Patients List")
            
            print("3. Display the Historty of doctor")
            
            print("4. Display the History of Patient")
            
            print("5. Display the OPD Details")
            
            print("6. Max Diagnose(chart)")
            
            print("7. Back to Main Menu")
            
            choice = int(input("enter your choice: "))
            
            if choice == 1:
                # function call
                rec_doctorslist()
                
            elif choice == 2:
                # function call
                rec_patientlist()
                
            elif choice == 3:
                # function call
                rec_doctorhistory()
                
            elif choice == 4:
                # function call
                rec_patienthistory()
                
            elif choice == 5:
                # function call
                rec_opdhistory()
                
            elif choice == 6:
                # function call
                rec_diagnosechart()
            
            elif choice == 7:
                # function call
                print("Back to Main Menu")
                
                # breaking out of the loop
                
                break
                
        else:
            print("Invalid entry")
            
    elif choice == 5:    
        
        print("======================================= Exit =======================================")
        
        print("======================================= Good Bye. Have a Good Day:) =======================================")
        
        # breaking out of the loop
        break
# Out:
# The connection is established
# The connection is established
# The connection is established
# The connection is established
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# ======================================= Hospital Management System =======================================
# 1. OPD
# 2. Doctor Details
# 3. Appoinment
# 4. Reports
# 5. Exit
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# Enter Your Choice: 1
# ======================================= OPD DETAILS =======================================
# 1. New Entry of OPD
# 2. Edit or Modify the details of OPD
# 3. Delete OPD
# 4. Search OPD
# 5. Back to Main Menu
# enter your choice: 5
# Back to Main Menu
#  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =  =
# ...
